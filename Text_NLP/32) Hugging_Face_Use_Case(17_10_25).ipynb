# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
classifier= pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
classifier('Gen AI is looking good for future endevours')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9980456829071045}]

# %%
inputs=['Learning AI is more interesting and easy','Hardware compatibily makes more difficult and tough']

# %%
classifier(inputs)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9956182241439819},
#  {'label': 'NEGATIVE', 'score': 0.9987366795539856}]

# %%
from transformers import  AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer= AutoTokenizer.from_pretrained('bert-base-uncased')

# %%
model= AutoModelForSequenceClassification.from_pretrained('bert-base-uncased')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
classifier= pipeline('sentiment-analysis',tokenizer=tokenizer,model=model)
# Out:
# Device set to use cuda:0

# %%
classifier('iam very happy')
# Out:
# [{'label': 'LABEL_0', 'score': 0.6427624821662903}]
